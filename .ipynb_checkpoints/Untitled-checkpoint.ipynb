# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('neos.csv')

# %%
data.head(5)
data.shape
# Out:
# (4426, 17)

# %%
plt.figure(figsize=(17,17))

sns.heatmap(data.corr(),
            linewidths = 0.25,
            square = False,
            cmap = 'inferno',
            linecolor = 'black',
            annot= True);

# %%
plt.figure(figsize=(20,10))
plt.scatter(data['estimated_max_diameter_kilometers'], data['miss_distance_kilometers'], alpha = 1, color = 'red');
plt.xlabel("estimated_max_diameter_kilometers", fontsize=20);
plt.ylabel("miss_distance_kilometers", fontsize=20);
plt.title("Asteroid Size vs Proximity to Earth", fontsize=30);
plt.grid();

plt.show()

# %%
small_neos = data['estimated_max_diameter_kilometers'] < 1
actual_small_neos = data['estimated_max_diameter_kilometers'][small_neos]
small_neos_miss_dist = data['miss_distance_kilometers'][small_neos]

actual_small_neos.size
# Out:
# 4144

# %%
small_neos_miss_dist.size
# Out:
# 4144

# %%
plt.figure(figsize=(20,10))
plt.scatter(actual_small_neos, small_neos_miss_dist, alpha = 1, color = 'red');
plt.xlabel("estimated_max_diameter_kilometers", fontsize=20);
plt.ylabel("miss_distance_kilometers", fontsize=20);
plt.title("Asteroid Size vs Proximity to Earth", fontsize=30);
plt.grid();

plt.show()

# %%
plt.figure(figsize=(20,10))
sorted_small_neos = sorted(actual_small_neos)
plt.plot(sorted_small_neos)
plt.grid()
plt.show()

# %%
data['close_approach_date'] = pd.to_datetime(data['close_approach_date'])

mask = (data['close_approach_date'] >= pd.to_datetime('2018-1-01')) & (data['close_approach_date'] <= pd.to_datetime('2018-1-31'))
        
        
data.loc[mask]
# Out:
#      absolute_magnitude_h close_approach_date  miss_distance_astronomical  \
# 0                    18.9          2018-01-01                    0.263140
# 1                    20.4          2018-01-01                    0.328489
# 2                    25.2          2018-01-01                    0.322390
# 3                    25.5          2018-01-01                    0.425473
# 4                    23.0          2018-01-01                    0.468737
# ..                    ...                 ...                         ...
# 359                  18.5          2018-01-31                    0.228082
# 360                  20.5          2018-01-31                    0.135032
# 361                  21.9          2018-01-31                    0.197419
# 362                  22.9          2018-01-31                    0.188032
# 363                  26.1          2018-01-31                    0.491619
#
#      miss_distance_lunar  miss_distance_kilometers  miss_distance_miles  \
# 0             102.361380              3.936515e+07         2.446037e+07
# 1             127.782398              4.914132e+07         3.053500e+07
# 2             125.409729              4.822886e+07         2.996803e+07
# 3             165.509104              6.364990e+07         3.955021e+07
# 4             182.338703              7.012206e+07         4.357183e+07
# ..                   ...                       ...                  ...
# 359            88.723924              3.412059e+07         2.120155e+07
# 360            52.527321              2.020045e+07         1.255198e+07
# 361            76.796091              2.953350e+07         1.835127e+07
# 362            73.144564              2.812923e+07         1.747869e+07
# 363           191.239940              7.354521e+07         4.569888e+07
#
#      relative_velocity_kph  relative_velocity_kps  relative_velocity_mph  \
# 0             86858.271008              24.127298           53970.351783
# 1             63362.517149              17.600699           39371.004059
# 2             52407.889230              14.557747           32564.224283
# 3             53336.019630              14.815561           33140.928419
# 4             30451.899059               8.458861           18921.625835
# ..                     ...                    ...                    ...
# 359           78269.940840              21.741650           48633.897407
# 360           20782.461345               5.772906           12913.413273
# 361           64486.732167              17.912981           40069.547551
# 362           28357.791507               7.877164           17620.428840
# 363           37656.217214              10.460060           23398.108968
#
#      estimated_max_diameter_kilometers  estimated_min_diameter_kilometers  \
# 0                             0.986370                           0.441118
# 1                             0.494356                           0.221083
# 2                             0.054205                           0.024241
# 3                             0.047211                           0.021113
# 4                             0.149293                           0.066766
# ..                                 ...                                ...
# 359                           1.185878                           0.530341
# 360                           0.472106                           0.211132
# 361                           0.247765                           0.110804
# 362                           0.156329                           0.069913
# 363                           0.035813                           0.016016
#
#      estimated_max_diameter_miles  estimated_min_diameter_miles       id  \
# 0                        0.612902                      0.274098  2189173
# 1                        0.307179                      0.137374  3078262
# 2                        0.033681                      0.015063  3703547
# 3                        0.029335                      0.013119  3581599
# 4                        0.092766                      0.041486  3635077
# ..                            ...                           ...      ...
# 359                      0.736870                      0.329538  2513529
# 360                      0.293353                      0.131192  2208023
# 361                      0.153954                      0.068850  3606253
# 362                      0.097138                      0.043442  3781875
# 363                      0.022253                      0.009952  3836294
#
#      is_potentially_hazardous  is_sentry_object                name
# 0                       False             False   189173 (2002 XY4)
# 1                        True             False           (2001 LD)
# 2                       False             False         (2015 AN44)
# 3                       False             False          (2011 TP6)
# 4                       False             False         (2013 HO11)
# ..                        ...               ...                 ...
# 359                     False             False   513529 (2010 CR1)
# 360                      True             False  208023 (1999 AQ10)
# 361                      True             False           (2012 OQ)
# 362                     False             False         (2017 SL14)
# 363                     False             False          (2018 WE1)
#
# [364 rows x 17 columns]
